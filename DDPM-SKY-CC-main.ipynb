# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Paths & Directories

# %%
REPO_DIR ="/content/drive/MyDrive/Research/skyreseach" # PLEASE CHANGE THIS ACCORDINLY
# %cd {REPO_DIR}
# Out:
# /content/drive/MyDrive/Research/skyreseach

# %%
import sys, os
sys.path.insert(0,os.getcwd())

# %% [markdown]
# # Install dependences

# %%
# %pip install -r requirements.txt  # Installing requirements

# %% [markdown]
# Before this step Ensure imports and see system root

# %% [markdown]
# # Prepare Data
#
# Select between the config files if you want to run 25% of the data set using less GPU work load i.e T4 and run 100% for large patch traning using heavy GPU workload i.e H100 and above
#
# - wind_3D16X16.npy is gerneated
# - wind_3D16X16.npy too
#
# > change  `--sample_fraction 0.25 \` to `--sample_fraction 1.0 \` for full data

# %%
import sys, os
sys.path.insert(0, os.getcwd())

# %run scripts/prepare_data.py \
  --folder_path /content/drive/MyDrive/Research/skyreseach/Data/training_data \
  --sample_fraction 0.25 \
  --image_size 16 \
  --output_images /content/drive/MyDrive/Research/skyreseach/wind_3D16X16.npy
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in safe_execfile(self, fname, exit_ignore, raise_exceptions, shell_futures, *where)
#    2830                 glob, loc = (where + (None, ))[:2]
# -> 2831                 py3compat.execfile(
#    2832                     fname, glob, loc,
#
# /usr/local/lib/python3.12/dist-packages/IPython/utils/py3compat.py in execfile(fname, glob, loc, compiler)
#     167         compiler = compiler or compile
# --> 168         exec(compiler(f.read(), fname, 'exec'), glob, loc)
#     169
#
# /content/drive/MyDrive/Research/skyreseach/scripts/prepare_data.py in <module>
#      20
# ---> 21     prepare_wind_speed_dataset(
#      22         folder_path=args.folder_path,
#
# ...

# %%
import numpy as np
imgs = np.load("/content/drive/MyDrive/Research/skyreseach/wind_3D16X16.npy")
print("N images:", imgs.shape[0])
# Out:
# N images: 130862

# %% [markdown]
# # Generate Noise Data

# %%
IMAGES_NP = "/content/drive/MyDrive/Research/skyreseach/wind_3D16X16.npy"

# %run scripts/pregenerate_noise.py \
  --images_np {IMAGES_NP} \
  --timesteps 500 \
  --height 16 \
  --channels 3 \
  --save_dir /content/drive/MyDrive/Research/skyreseach/pregenerated_noise/ \
  --images_per_file 1000
# Out:
# Loading images from: /content/drive/MyDrive/Research/skyreseach/wind_3D16X16.npy
# Inferred n_images from file: 130862
# ...
# Pre-generating Noise for DDPM Training
# ...
# Dataset size: 130862 images
# Timesteps: 500
# Image dimensions: 16×16×3
# Images per file: 1000
#
# Estimated storage: 187.20 GB
# ...
#
# Do you want to continue? This will take hours! (yes/no): yes
#
# Generating noise...
# Chunks:   1%|          | 1/131 [00:30<1:05:55, 30.43s/it]
# Saved /content/drive/MyDrive/Research/skyreseach/pregenerated_noise/noise_chunk_0000.npy (1464.8 MB) - Images 0 to 999
# Chunks:   2%|▏         | 2/131 [01:08<1:15:14, 35.00s/it]
# Saved /content/drive/MyDrive/Research/skyreseach/pregenerated_noise/noise_chunk_0001.npy (1464.8 MB) - Images 1000 to 1999
# Chunks:   2%|▏         | 3/131 [01:47<1:18:09, 36.64s/it]
# Saved /content/drive/MyDrive/Research/skyreseach/pregenerated_noise/noise_chunk_0002.npy (1464.8 MB) - Images 2000 to 2999
# Chunks:   2%|▏         | 3/131 [02:05<1:29:26, 41.93s/it]
# ...

# %% [markdown]
# # Check Configuration
#
# Checking the config for training is correct and all paths are correct with desired training fraction.

# %%
import yaml

def load_config(cfg_path):
    with open(cfg_path, "r") as f:
        return yaml.safe_load(f)

cfg = load_config("/content/drive/MyDrive/Research/skyreseach/config/train_25pct.ymal")
print(cfg["dataset"]["fraction"])
print(cfg["wandb"]["enabled"])

# %% [markdown]
# # Training

# %%
# %run scripts/train_cli.py --config /content/drive/MyDrive/Research/skyreseach/config/train_25pct.ymal
